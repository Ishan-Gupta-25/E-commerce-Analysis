# %%
import numpy as np
import pandas as pd
import matplotlib as mp

# %%
df=pd.read_csv("C:\\Users\\Ishan\\OneDrive\\Desktop\\E-comerce Analysis\\ecommerce_customer_data.csv")

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.describe()
# Out:
#        Customer_ID          Age  Annual_Income  Spending_Score  \
# count  2000.000000  2000.000000    2000.000000     2000.000000
# mean   1000.500000    43.805500   84089.382500       50.448500
# std     577.494589    14.929203   37446.608502       28.411793
# min       1.000000    18.000000   20112.000000        1.000000
# 25%     500.750000    31.000000   50810.750000       25.000000
# 50%    1000.500000    44.000000   84476.500000       50.500000
# 75%    1500.250000    56.000000  115550.750000       75.250000
# max    2000.000000    69.000000  149936.000000       99.000000
#
#        Membership_Years  Online_Purchases  Discount_Usage        Churn
# count       2000.000000       2000.000000     2000.000000  2000.000000
# mean           5.248000         97.976000        0.489155     0.310500
# std            2.759783         57.314858        0.281573     0.462814
# min            0.500000          1.000000        0.000000     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       2000 non-null   int64
#  1   Age               2000 non-null   int64
#  2   Gender            2000 non-null   object
#  3   Annual_Income     2000 non-null   int64
#  4   Spending_Score    2000 non-null   int64
#  5   Membership_Years  2000 non-null   float64
#  6   Online_Purchases  2000 non-null   int64
#  7   Discount_Usage    2000 non-null   float64
#  8   Churn             2000 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 140.8+ KB

# %%
df.isnull().sum()
# Out:
# Customer_ID         0
# Age                 0
# Gender              0
# Annual_Income       0
# Spending_Score      0
# Membership_Years    0
# Online_Purchases    0
# Discount_Usage      0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Annual_Income', 'Spending_Score',
#        'Membership_Years', 'Online_Purchases', 'Discount_Usage', 'Churn'],
#       dtype='object')

# %%
df.columns=df.columns.str.lower()

# %%
df.columns=df.columns.str.replace(" " , "_")

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'annual_income', 'spending_score',
#        'membership_years', 'online_purchases', 'discount_usage', 'churn'],
#       dtype='object')

# %%
df.describe()
# Out:
#        customer_id          age  annual_income  spending_score  \
# count  2000.000000  2000.000000    2000.000000     2000.000000
# mean   1000.500000    43.805500   84089.382500       50.448500
# std     577.494589    14.929203   37446.608502       28.411793
# min       1.000000    18.000000   20112.000000        1.000000
# 25%     500.750000    31.000000   50810.750000       25.000000
# 50%    1000.500000    44.000000   84476.500000       50.500000
# 75%    1500.250000    56.000000  115550.750000       75.250000
# max    2000.000000    69.000000  149936.000000       99.000000
#
#        membership_years  online_purchases  discount_usage        churn
# count       2000.000000       2000.000000     2000.000000  2000.000000
# mean           5.248000         97.976000        0.489155     0.310500
# std            2.759783         57.314858        0.281573     0.462814
# min            0.500000          1.000000        0.000000     0.000000
# ...

# %%
# !pip install pymysql mysql-connector-python pandas cryptography sqlalchemy

# %%
# SQL JOINING
import mysql.connector
import pandas as pd
from mysql.connector import Error
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# %%
url = URL.create(
    drivername="mysql+mysqlconnector",
    username="root",
    password="Ishan@9140",
    host="127.0.0.1",
    database="major"
)

# %%
engine = create_engine(url)
engine.connect()
print("Engine Connected")

table_name="customer"

# Upload data frame yo my sql
df.to_sql(table_name, engine, if_exists='replace', index=False)
print("CONNECTION SUCCESSFUL!")
# Out:
# Engine Connected
# CONNECTION SUCCESSFUL!

# %%
df.describe()
# Out:
#        customer_id          age  annual_income  spending_score  \
# count  2000.000000  2000.000000    2000.000000     2000.000000
# mean   1000.500000    43.805500   84089.382500       50.448500
# std     577.494589    14.929203   37446.608502       28.411793
# min       1.000000    18.000000   20112.000000        1.000000
# 25%     500.750000    31.000000   50810.750000       25.000000
# 50%    1000.500000    44.000000   84476.500000       50.500000
# 75%    1500.250000    56.000000  115550.750000       75.250000
# max    2000.000000    69.000000  149936.000000       99.000000
#
#        membership_years  online_purchases  discount_usage        churn
# count       2000.000000       2000.000000     2000.000000  2000.000000
# mean           5.248000         97.976000        0.489155     0.310500
# std            2.759783         57.314858        0.281573     0.462814
# min            0.500000          1.000000        0.000000     0.000000
# ...

# %%
df.head()
# Out:
#    customer_id  age  gender  annual_income  spending_score  membership_years  \
# 0            1   56    Male          69812              88               3.2
# 1            2   69  Female          70500              26               4.3
# 2            3   46  Female          99151              17               8.2
# 3            4   32    Male          78643              71               0.6
# 4            5   60  Female          64900              13               6.7
#
#    online_purchases  discount_usage  churn
# 0                92            0.43      1
# 1                30            0.23      1
# 2               199            0.52      0
# 3               153            0.25      0
# 4               127            0.94      0

# %%
print(df.columns)
# Out:
# Index(['customer_id', 'age', 'gender', 'annual_income', 'spending_score',
#        'membership_years', 'online_purchases', 'discount_usage', 'churn'],
#       dtype='object')

# %%
# Use 'spending_score' instead of 'Review Rating'
df['spending_score'] = df.groupby('annual_income')['spending_score'].transform(lambda x: x.fillna(x.median()))

# %%
print(df.columns)
# Out:
# Index(['customer_id', 'age', 'gender', 'annual_income', 'spending_score',
#        'membership_years', 'online_purchases', 'discount_usage', 'churn'],
#       dtype='object')

# %%
df.head()
# Out:
#    customer_id  age  gender  annual_income  spending_score  membership_years  \
# 0            1   56    Male          69812              88               3.2
# 1            2   69  Female          70500              26               4.3
# 2            3   46  Female          99151              17               8.2
# 3            4   32    Male          78643              71               0.6
# 4            5   60  Female          64900              13               6.7
#
#    online_purchases  discount_usage  churn
# 0                92            0.43      1
# 1                30            0.23      1
# 2               199            0.52      0
# 3               153            0.25      0
# 4               127            0.94      0

# %%
labels=['Young Adult', 'Adult', 'Middle-Aged', 'Senior']
df['age_group']=pd.qcut(df['age'], q=4, labels=labels)

# %%
df.head(20)
# Out:
#     customer_id  age  gender  annual_income  spending_score  membership_years  \
# 0             1   56    Male          69812              88               3.2
# 1             2   69  Female          70500              26               4.3
# 2             3   46  Female          99151              17               8.2
# 3             4   32    Male          78643              71               0.6
# 4             5   60  Female          64900              13               6.7
# 5             6   25  Female          62946              69               6.9
# 6             7   38  Female          27851              26               8.1
# 7             8   56    Male          36288              49               9.4
# 8             9   36  Female          92692              67               0.7
# 9            10   40  Female          87580               7               2.0
# 10           11   28    Male          27368              58               8.9
# ...

# %%
#removes the row from the data-tabel
df=df.drop('age',axis=1)

# %%
df.head(50)
# Out:
#     customer_id  gender  annual_income  spending_score  membership_years  \
# 0             1    Male          69812              88               3.2
# 1             2  Female          70500              26               4.3
# 2             3  Female          99151              17               8.2
# 3             4    Male          78643              71               0.6
# 4             5  Female          64900              13               6.7
# 5             6  Female          62946              69               6.9
# 6             7  Female          27851              26               8.1
# 7             8    Male          36288              49               9.4
# 8             9  Female          92692              67               0.7
# 9            10  Female          87580               7               2.0
# 10           11    Male          27368              58               8.9
# 11           12    Male         105436              49               4.9
# ...
